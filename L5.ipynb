# %%
#Answer of 1
def isInt(n):
    try:
        int(n)
        return True
    except:
        return False

def prime_or_composite(n):
        has_divisor = False
        for i in range(2, n):
            if n % i == 0:
               has_divisor = True
        if has_divisor:
            print(n, 'is composite.')
        else:
            print(n, 'is prime.')


n = input("Enter a number: ")

if isInt(n):
    composites = []
    primes = []
    for i in range(2, int(n)+1):
        if not prime_or_composite(i):
            primes.append(str(i))
        else:
            composites.append(str(i))

    f = open("primes.txt", "w")
    data = " ".join(primes)
    f.write(data)
    f.close()
    f = open("composites.txt", "w")
    data = " ".join(composites)
    f.write(data)
    f.close()
else:
    print("Provided invalid input.")
# Out:
# Enter a number: 13
# 2 is prime.
# 3 is prime.
# 4 is composite.
# 5 is prime.
# 6 is composite.
# 7 is prime.
# 8 is composite.
# 9 is composite.
# 10 is composite.
# 11 is prime.
# 12 is composite.
# 13 is prime.

# %%
#Answer of 2
welcome = str('How are you')
print(welcome)
words = welcome.split()
print(words)
number_of_words = len(words)
print (number_of_words)
# Out:
# How are you
# ['How', 'are', 'you']
# 3

# %%
#Answer of 3
words = input("Enter a sentence: ").split()
total = 0

for word in words:
    total += len(word)

print("Average word length is " + str(total / len(words)))
# Out:
# Enter a sentence: hello my love
# Average word length is 3.6666666666666665

# %%
#Answer of 4
def fact(n):
  res = 1;   
  for i in range(2,n+1):   
   res = res * i;   
  return res;   
def comb(N, k):
  if k <= N:
   return fact(N) / (fact(k) * fact(N-k))
  else:
   return 0  
N=int(input("Enter N items: "))
k=int(input("Enter k value: "))
combination=comb(N,k)
print(combination)
# Out:
# Enter N items: 5
# Enter k value: 2
# 10.0

# %%
#Answer of 5
n1 = int(input('Enter first number: '))
n2 = int(input('Enter second number: '))

a = 1

if n1>n2:
    l = n1
else:
    l = n2

while True:
    if n1>0:
        z = n1*a
        a+=1
        if z%n2 == 0:
            print(z, ' is the LCM.')
            break
    
    else:
        print(0)
# Out:
# Enter first number: 3
# Enter second number: 4
# 12  is the LCM.
